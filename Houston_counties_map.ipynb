# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np


img=mpimg.imread('./Houston-county-map.png',0)

plt.title ('Houston Metropolitan Counties')
plt.savefig('Houston-Counties.png')
plt.imshow(img)
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>
